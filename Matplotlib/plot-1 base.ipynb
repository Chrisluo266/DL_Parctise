# %%
import numpy as np
import pylab as plt

# %%
x1 = np.linspace(-1,1,1000)
y1 = 10*x1**2-5

x2 = x1
y2 = 2*x1+1

plt.figure(figsize=[10,5])
plt.plot(x1,y1,linewidth=0.5,linestyle="-")
plt.plot(x2,y2,color='#ff0000',linestyle='-.')

plt.show()
