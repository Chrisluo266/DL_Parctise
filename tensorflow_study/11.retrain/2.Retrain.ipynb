# %%
# %%cmd
# python ./retrain.py --image_dir=./dataset/flower_photos/ ^
# --output_graph=./graph/output_graph.pb ^
# --output_labels=./graph/output_labels.txt ^
# --learning_rate=0.001 ^
# --train_batch_size=64 ^
# --test_batch_size=64 ^
# --validation_batch_size=64 ^
# --bottleneck_dir=./graph/bottleneck ^
# --tfhub_module=https://tfhub.dev/google/imagenet/inception_v3/feature_vector/3
# Out:
# Microsoft Windows [版本 10.0.17134.765]
# (c) 2018 Microsoft Corporation。保留所有权利。
#
# F:\JupyterRoot\DL_Parctise\tensorflow_study\11.retrain>python ./retrain.py --image_dir=./dataset/flower_photos/ ^
# More? --output_graph=./graph/output_graph.pb ^
# More? --output_labels=./graph/output_labels.txt ^
# More? --learning_rate=0.001 ^
# More? --train_batch_size=64 ^
# More? --test_batch_size=64 ^
# More? --validation_batch_size=64 ^
# More? --bottleneck_dir=./graph/bottleneck ^
# More? --tfhub_module=https://tfhub.dev/google/imagenet/inception_v3/feature_vector/3
#
# F:\JupyterRoot\DL_Parctise\tensorflow_study\11.retrain>
# WARNING: Logging before flag parsing goes to stderr.
# W0609 16:02:36.247637 18620 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# INFO:tensorflow:Looking for images in 'daisy'
# I0609 16:02:36.674524 18620 retrain.py:185] Looking for images in 'daisy'
# INFO:tensorflow:Looking for images in 'dandelion'
# ...
