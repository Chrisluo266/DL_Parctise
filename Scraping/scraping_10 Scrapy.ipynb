# %% [markdown]
# ## scrapy爬虫
# <p>直接执行scraping_10-Scrapy.py</p>

# %%
# %%cmd
# scrapy runspider scraping_10-Scrapy.py -o res.json
# Out:
# Microsoft Windows [版本 10.0.17134.706]
# (c) 2018 Microsoft Corporation。保留所有权利。
#
# F:\JupyterRoot\scraping>scrapy runspider scraping_10-Scrapy.py -o res.json
#
# F:\JupyterRoot\scraping>
# 2019-04-26 12:29:40 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: scrapybot)
# 2019-04-26 12:29:40 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.0, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1a  20 Nov 2018), cryptography 2.4.2, Platform Windows-10-10.0.17134-SP0
# 2019-04-26 12:29:40 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'json', 'FEED_URI': 'res.json', 'SPIDER_LOADER_WARN_ONLY': True}
# 2019-04-26 12:29:40 [scrapy.extensions.telnet] INFO: Telnet Password: 41f70911a822288b
# 2019-04-26 12:29:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...
